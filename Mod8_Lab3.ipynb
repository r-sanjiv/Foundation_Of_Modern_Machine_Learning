# %% [markdown]
# <a href="https://colab.research.google.com/github/r-sanjiv/Foundation_Of_Modern_Machine_Learning/blob/main/Mod8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-07-11 09:35:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   220MB/s    in 0.3s
#
# 2022-07-11 09:35:49 (220 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 878     1412.7419v5  Stochastic gradient algorithms have been the m...    cs
# 17790  1803.00353v1  Monolingual data have been demonstrated to be ...    cs
# 21091  1707.07907v3  Training robots for operation in the real worl...    cs
# 30656  1712.09448v1  While the basic laws of Newtonian mechanics ar...    cs
# 7817   1803.05976v1  Travel providers such as airlines and on-line ...  stat
# ...             ...                                                ...   ...
# 3208    1402.0170v1  The challenge of object categorization in imag...    cs
# 6356   1611.06652v1  Adaptive stochastic gradient methods such as A...  stat
# 21969   1112.2289v1  Exact inference in the linear regression model...  stat
# 2155   1610.06940v3  Deep neural networks have achieved impressive ...    cs
# 7279   1711.06795v1  Most multi-class classifiers make their predic...  stat
#
#                                                    title  year  \
# 878    ADASECANT: Robust Adaptive Secant Method for S...  2014
# 17790  Joint Training for Neural Machine Translation ...  2018
# 21091                 Mutual Alignment Transfer Learning  2017
# 30656  Taking Visual Motion Prediction To New Heightf...  2017
# 7817   Deep Choice Model Using Pointer Networks for A...  2018
# ...                                                  ...   ...
# 3208              Collaborative Receptive Field Learning  2014
# 6356   Scalable Adaptive Stochastic Optimization Usin...  2016
# 21969  Convergent Expectation Propagation in Linear M...  2011
# 2155         Safety Verification of Deep Neural Networks  2016
# 7279   Prediction Scores as a Window into Classifier ...  2017
#
#                                                 keywords
# 878    [stochastic, algorithms, important, successes,...
# 17790  [monolingual, demonstrated, improving, transla...
# 21091  [operation, consuming, potentially, expensive,...
# 30656  [newtonian, mechanics, understood, explaining,...
# 7817   [providers, interested, understanding, passeng...
# ...                                                  ...
# 3208   [challenge, categorization, arbitrary, transla...
# 6356   [stochastic, popularity, particular, maintains...
# 21969  [inference, regression, intractable, expectati...
# 2155   [impressive, experimental, classification, sur...
# 7279   [classifiers, prediction, selecting, analyzing...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 878      [stochastic, algorithms, important, successes,...
# 17790    [monolingual, demonstrated, improving, transla...
# 21091    [operation, consuming, potentially, expensive,...
# 30656    [newtonian, mechanics, understood, explaining,...
# 7817     [providers, interested, understanding, passeng...
#                                ...
# 23001    [uncertainty, increasingly, scientific, enviro...
# 33179    [considers, metalearning, distribution, presen...
# 37455    [describes, interplay, distributed, knowledge,...
# 37402    [singularity, arguments, technological, singul...
# 33585    [restricted, boltzmann, demonstrated, efficien...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8792 words.
# Out of those 4585 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4e6cd985-bf34-45bd-b41b-bba3ed996c50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e6cd985-bf34-45bd-b41b-bba3ed996c50")) {                    Plotly.newPlot(                        "4e6cd985-bf34-45bd-b41b-bba3ed996c50",                        [{"x":["automatically","algorithm","stochastic","experiments","curvature","estimated","information","gradients","algorithms","successes","preliminary","performance","important","estimates","reduction","convergence","statistics","technique","iteration","simultaneously","especially","experiment","translate","monolingual","iteratively","outperforming","optimization","improving","including","incrementally","leveraging","demonstrated","decreasing","adaptation","significantly","direction","statistical","translation","generated","calibration","auxiliary","supplemental","alignment","applications","potentially","harnesses","proficiency","exploration","developed","empirically","complexity","significant","requirements","simulator","reinforcement","simulation","reciprocal","imperfect","simulations","behaviour","optimally","operation","demonstrate","consuming","expensive","approaches","newtonian","extrapolate","understood","arbitrary","internally","resultant","competitive","orientation","researchers","parameters","transitions","authoring","mechanical","architecture","mechanics","equations","predictions","scenarios","processes","unfortunately","investigate","intelligence","explaining","approximation","prediction","estimating","uncertainties","associated","artificial","homogeneous","environment","recurrent","techniques","capabilities","extrapolation","handcrafted","improvements","implicitly","challenging","characterize","experimental","filtering","passengers","alternative","providers","historically","traditional","particular","simplicity","understanding","modelling","passenger","outperforms","conditions","positions","attention","probability","itinerary","assumptions","industrial","shortcomings","evaluated","conditional","multinomial","mechanism","knowledge","concentrate","therefore","attributes","presented","interested","searching","different","classical","alternatives","difficulties","correspond","practical","approached","mainstream","treatment","proposing","regardless","treatments","discusses","theoretical","cumulative","continuous","integrated","collection","conclusion","participants","extensive","equivalent","sometimes","objective","optimality","additionally","synthetic","nonnegativity","stationary","nonnegative","factorization","comparing","decomposition","guarantees","constraints","evaluation","conducted","clustering","utilizing","justification","equivalence","capability","performances","challenge","opportunity","diversity","fundamental","exploiting","invariant","uncertainty","platforms","importance","computational","confidence","diversities","effectiveness","recognition","automatic","properties","separated","configurations","availability"],"y":[178,819,133,545,13,60,698,24,580,15,46,912,349,63,90,114,59,279,47,127,112,90,14,7,24,19,312,102,252,20,48,89,11,56,245,49,172,121,165,22,18,2,54,449,47,3,3,62,203,79,238,256,58,16,116,82,5,14,60,31,18,40,558,29,73,433,1,3,24,82,2,7,124,15,67,249,12,3,6,249,10,20,84,96,120,32,141,81,19,132,221,76,12,96,130,13,113,139,378,50,2,14,130,20,266,59,388,49,2,93,5,3,170,290,32,154,56,3,257,139,22,192,183,1,63,20,10,134,96,6,126,385,7,140,66,169,37,34,739,89,31,31,30,132,8,2,29,18,15,7,14,141,11,109,61,61,22,13,156,56,22,175,19,66,126,1,24,11,32,70,60,55,152,244,60,154,45,9,25,47,46,166,5,40,73,97,63,87,30,78,277,48,2,197,364,202,237,6,36,27],"type":"bar"},{"x":["automatically","algorithm","stochastic","experiments","curvature","estimated","information","gradients","a ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4585,), (4585, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Joint</span> <span style=''>Sequence</span> <span style=''>Learning</span> <span style=''>and</span> <span style=''>Cross</span> <span style=''>Modality</span> <span style='background-color:rgba(0, 255, 0, 0.6842105263157894);'>Convolution</span> <span style=''>for</span> <span style=''>3D</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Biomedical</span> <span style='background-color:rgba(0, 255, 0, 0.7012448132780082);'>Segmentation</span> <br/><br/><span style=''>Deep</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.6274089935760171);'>convolutional</span> <span style=''>neural</span> <span style=''>net</span> <span style=''>work</span> <span style=''>have</span> <span style=''>been</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>3D</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biomedical</span> <span style='background-color:rgba(0, 255, 0, 0.7012448132780082);'>segmentation</span> <span style=''>and</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>However</span> <span style=''>most</span> <span style=''>of</span> <span style=''>them</span> <span style=''>often</span> <span style=''>adapt</span> <span style=''>a</span> <span style=''>single</span> <span style=''>modality</span> <span style=''>or</span> <span style=''>stack</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.65);'>modalities</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>input</span> <span style=''>channels</span> <span style=''>To</span> <span style=''>better</span> <span style=''>leverage</span> <span style=''>the</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.65);'>modalities</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>encoder</span> <span style=''>decoder</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>with</span> <span style=''>cross</span> <span style=''>modality</span> <span style='background-color:rgba(0, 255, 0, 0.6842105263157894);'>convolution</span> <span style=''>layers</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.65);'>modalities</span> <span style=''>of</span> <span style=''>MRI</span> <span style=''>data</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>exploit</span> <span style='background-color:rgba(0, 255, 0, 0.6274089935760171);'>convolutional</span> <span style=''>LSTM</span> <span style=''>to</span> <span style=''>model</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>2D</span> <span style=''>slices</span> <span style=''>and</span> <span style=''>jointly</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.65);'>modalities</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6274089935760171);'>convolutional</span> <span style=''>LSTM</span> <span style=''>in</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>manner</span> <span style=''>To</span> <span style=''>avoid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converging</span> <span style=''>to</span> <span style=''>the</span> <span style=''>certain</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Stratified</span> <span style=''>Analysis</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Causation</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>new</span> <span style=''>formulas</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>causation</span> <span style=''>difined</span> <span style=''>by</span> <span style=''>Pearl</span> <span style=''>(2000)</span> <span style=''>Tian</span> <span style=''>and</span> <span style=''>Pearl</span> <span style=''>(2000a</span> <span style=''>2000b)</span> <span style=''>showed</span> <span style=''>how</span> <span style=''>to</span> <span style=''>bound</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantities</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>causation</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>data</span> <span style=''>under</span> <span style=''>the</span> <span style=''>minimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>about</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>process</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>narrower</span> <span style=''>bounds</span> <span style=''>than</span> <span style=''>Tian</span> <span style=''>Pearl</span> <span style=''>bounds</span> <span style=''>by</span> <span style=''>making</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>measured</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>studies</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifiable</span> <span style=''>case</span> <span style=''>under</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prevention</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>and</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>problem</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>viewpoint</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>accuracy</span> <span style=''>These</span> <span style=''>results</span> <span style=''>are</span> <span style=''>helpful</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>more</span> <span style=''>evidence</span> <span style=''>for</span> <span style=''>public</span> <span style=''>policy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assessment</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style='background-color:rgba(0, 255, 0, 0.3913043478260869);'>occurring</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>one</span> <span style=''>needs</span> <span style=''>to</span> <span style=''>ensure</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>lends</span> <span style=''>itself</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>In</span> <span style=''>cases</span> <span style=''>where</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>computed</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>tractably</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3548387096774193);'>beneficial</span> <span style=''>to</span> <span style=''>have</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.36046511627906974);'>guarantees</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>In</span> <span style=''>order</span> <span style=''>operate</span> <span style=''>under</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>are</span> <span style=''>cast</span> <span style=''>under</span> <span style=''>the</span> <span style=''>umbrella</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5483870967741935);'>convexity</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.375);'>submodularity</span> <span style=''>In</span> <span style=''>this</span> <span style=''>report</span> <span style=''>we</span> <span style=''>will</span> <span style=''>study</span> <span style=''>design</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>over</span> <span style=''>a</span> <span style=''>common</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>Set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>submodular</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style='background-color:rgba(0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independence</span> <span style=''>Testing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independence</span> <span style=''>Testing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Modelling</span> <br/><br/><span style=''>Testing</span> <span style=''>(conditional)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>is</span> <span style=''>a</span> <span style=''>task</span> <span style=''>central</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>in</span> <span style=''>general</span> <span style=''>though</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unfortunately</span> <span style=''>one</span> <span style=''>for</span> <span style=''>which</span> <span style=''>to</span> <span style=''>date</span> <span style=''>there</span> <span style=''>does</span> <span style=''>not</span> <span style=''>exist</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practicable</span> <span style=''>workflow</span> <span style=''>State</span> <span style=''>of</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>workflows</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heuristic</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subjective</span> <span style=''>manual</span> <span style=''>choices</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>or</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>We</span> <span style=''>address</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establishing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>link</span> <span style=''>between</span> <span style=''>multivariateconditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>testing</span> <span style=''>and</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>aka</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>task</span> <span style=''>This</span> <span style=''>link</span> <span style=''>allows</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>the</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1376374600922313)
# 	architecture (0.08832919474991131)
# 	segmentation (0.07272082298687478)
# 	different (0.2621496984746364)
# 	representation (0.13657325292656972)
# 	knowledge (0.13657325292656972)
# 	information (0.24760553387726145)
# 	detection (0.12664065271372826)
# 	recognition (0.12912380276693863)
# 	convolutional (0.13479957431713374)
#
# Some Statistics words are:
# 	stochastic (0.13023725391216556)
# 	variables (0.14235234729934376)
# 	theoretical (0.14790509843513377)
# 	statistical (0.16153457849570924)
# 	distribution (0.17768803634528016)
# 	estimation (0.16506814740030287)
# 	algorithm (0.39424533064109035)
# 	inference (0.2039374053508329)
# 	dimensional (0.18324078748107017)
# 	regression (0.19030792529025745)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4c13ac01-7f29-40b6-858e-7f7fbc0cea93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c13ac01-7f29-40b6-858e-7f7fbc0cea93")) {                    Plotly.newPlot(                        "4c13ac01-7f29-40b6-858e-7f7fbc0cea93",                        [{"x":["automatically","algorithm","stochastic","experiments","curvature","estimated","information","gradients","algorithms","successes","preliminary","performance","important","estimates","reduction","convergence","statistics","technique","iteration","simultaneously","especially","experiment","translate","monolingual","iteratively","outperforming","optimization","improving","including","incrementally","leveraging","demonstrated","decreasing","adaptation","significantly","direction","statistical","translation","generated","calibration","auxiliary","supplemental","alignment","applications","potentially","harnesses","proficiency","exploration","developed","empirically","complexity","significant","requirements","simulator","reinforcement","simulation","reciprocal","imperfect","simulations","behaviour","optimally","operation","demonstrate","consuming","expensive","approaches","newtonian","extrapolate","understood","arbitrary","internally","resultant","competitive","orientation","researchers","parameters","transitions","authoring","mechanical","architecture","mechanics","equations","predictions","scenarios","processes","unfortunately","investigate","intelligence","explaining","approximation","prediction","estimating","uncertainties","associated","artificial","homogeneous","environment","recurrent","techniques","capabilities","extrapolation","handcrafted","improvements","implicitly","challenging","characterize","experimental","filtering","passengers","alternative","providers","historically","traditional","particular","simplicity","understanding","modelling","passenger","outperforms","conditions","positions","attention","probability","itinerary","assumptions","industrial","shortcomings","evaluated","conditional","multinomial","mechanism","knowledge","concentrate","therefore","attributes","presented","interested","searching","different","classical","alternatives","difficulties","correspond","practical","approached","mainstream","treatment","proposing","regardless","treatments","discusses","theoretical","cumulative","continuous","integrated","collection","conclusion","participants","extensive","equivalent","sometimes","objective","optimality","additionally","synthetic","nonnegativity","stationary","nonnegative","factorization","comparing","decomposition","guarantees","constraints","evaluation","conducted","clustering","utilizing","justification","equivalence","capability","performances","challenge","opportunity","diversity","fundamental","exploiting","invariant","uncertainty","platforms","importance","computational","confidence","diversities","effectiveness","recognition","automatic","properties","separated","configurations","availability","mathematical","irrelevant","decoupled","overfitting","uniformity","emphasizes","recovering","exponentially","redundancy","difference","parametrization","multilayer","dependencies","conjecture","connected","hamiltonian","connection","recovered","spherical","annealing","independence","simulated","structure","increases","individual","strategies","administration","computing","sequential","variability","validation","currently","promising","oscillates","particularly","formulated","stimulating","potential","prospective","substantially","successfully","underlying","methodology","efficient","protocols","describes","comorbidity","efficiently","relevance","distribution","traintest","maintaining","classifier","stability","classifiers","stratification","perspective","stratifyi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	oscillates
# 	comorbidity
# 	parametrizations
# 	irregularly
# 	intercept
# 	methodologically
# 	normality
# 	transplantation
# 	detectability
# 	poisoning
# 	attackers
# 	profitable
# 	administrative
# 	parameterizations
# 	heteroscedasticity
# 	infectious
# 	censoring
# 	provision
# 	compounds
# 	fragmentation
# Some words which never appear in Statistics papers:
# 	monolingual
# 	supplemental
# 	proficiency
# 	authoring
# 	diversities
# 	repetitive
# 	conversation
# 	dialogues
# 	conversational
# 	operative
# 	hypothesised
# 	accelerator
# 	revolutionary
# 	political
# 	minkowski
# 	pollution
# 	customize
# 	nondeterministic
# 	situational
# 	technologists

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0511060259344013e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
